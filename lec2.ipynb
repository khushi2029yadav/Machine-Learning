# %%
x = 10;
print(x)
# Out:
# 10

# %%
# x = "Hii Khushi"
# print(x.upper())
# print(x.lower())
# print(x.capitalize())
# print(x.count(x))
# print(x)
# Out:
# HII KHUSHI
# hii khushi
# Hii khushi
# 1
# Hii Khushi

# %%
x="welcome.to,vedam,for,learning.machine.learning,"
x = x.replace(",", "#")
x = x.replace(".", ",")
x = x.replace("#","." )
print(x)
# Out:
# welcome,to.vedam.for.learning,machine,learning.

# %%
 x="welcome to vedam for learning machinel learning"
lst= x.split()
print(lst)
# Out:
# ['welcome', 'to', 'vedam', 'for', 'learning', 'machinel', 'learning']

# %%
# new_str = " --".join(lst)
new_str = " ".join(lst)
print(new_str)
# Out:
# welcome to vedam for learning machinel learning

# %%
a = "charie-bravo-alpha"

lst = a.split("-")
lst = lst[::-1]
lst = [i.upper() for i in lst]
ans = " ".join(lst)
print(ans)
# Out:
# ALPHA BRAVO CHARIE

# %%
b = " rahul KUMAR sharma "

print(b.title())
c = b.split()

found = True
for word in c:
  if not word.isalnum():
    found = False
    break
if valid:
  ans = "".join()
    print("Valid")
else:
   print("Invalid")
# Out:
#  Rahul Kumar Sharma
# Valid

# %%
d = " 45, 88, 72, 91, 60 "
marks = list(map(int, d.split(",")))
print(marks)


total=(sum(marks))
average = total/len(marks)
print("Total:", total)
print("Average:", average )
# Out:
# [45, 88, 72, 91, 60]
# Total: 356
# Average: 71.2

# %%
name = "Khushi"
age=19
print(f"Name of the student is {name} and age is {age}")
# Out:
# Name of the student is Khushi and age is 19
